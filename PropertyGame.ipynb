# %%
sys.path.append("/home/ubuntu/github/property_game/")
try:
    reload(pgame_analyze_lib)
except:
    import pgame_analyze_lib

from pgame_analyze_lib import *

matplotlib.rcParams.update({'font.size': 14})

rootDir = "/home/ubuntu/github/property_game/"

# %%
from mpl_toolkits.mplot3d import Axes3D
import plotly.plotly as py
from plotly.graph_objs import *
from scipy.interpolate import griddata

# %%
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':3}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':5}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':7}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':9}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':3}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':5}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':7}

# %%
configList = [{'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':1},
              {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':3},
              {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':5},
              {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':7},
              {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':9},
              {'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':11},
              {'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':13},
              {'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':18},
              {'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':24}]
#,
#              {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':3},
#              {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':5},
#              {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':7}]

# %%
export2plotly({'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':24})
# Out:
# u'https://plot.ly/~wazaahhh/208'

# %%
parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':11}
#resultDic = loadResults(parDic)
#dic = resultArray(resultDic,['perc_filled_sites','s','cooperators'])

dic = phase_transition(parDic,dRange=[0.8,1.1])
d = np.array(dic['d'])
c = np.array(dic['c'])
s = np.array(dic['s'])

o = np.argsort(c)
index = np.argwhere(c[o] > 0.50)[0]
print c[o][index],s[o][index],d[o][index]

index = np.argwhere(c[o] < 0.5)[-1]
print c[o][index],s[o][index],d[o][index]

index = np.argwhere((c[o] > 0.35)*(c[o] < 0.70))
print 'c' , c[o][index]
print 's' , s[o][index]
print 'd' , d[o][index]
# Out:
# [ 0.55151249] [ 0.] [ 0.95]
# [ 0.4909764] [ 0.] [ 0.9]
# c [[ 0.44814661]
#  [ 0.4909764 ]
#  [ 0.55151249]]
# s [[ 0.]
#  [ 0.]
#  [ 0.]]
# d [[ 1.  ]
#  [ 0.9 ]
#  [ 0.95]]

# %%
pl.figure(1,(13,10))
matplotlib.rcParams.update({'font.size': 22})
for parDic in configList:
    output = phase_transition(parDic,dRange=[0.39,0.61])
    #print parDic,output['s'],output['c']
    s = output['s']
    c = output['c']
    pl.plot(s,c,'s-',label="M=%s"%parDic['M'],lw=1)
pl.ylim(ymin=-0.1)
pl.xlabel("Property Violation s")
pl.ylabel("Cooperation Level after N=200 iterations")
pl.legend()
pl.savefig(rootDir + "figures/phase_transitions.eps")

# %%
parDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            's':0}

K = np.array(searchKeys(parDic))

M = []
for k in K:
    M = np.append(M,int(re.findall("_M(\d*?).json",k.name)[0])) 
o = np.argsort(M)


colorLine ={1:'green',3:'blue',5:'red', 7 : 'yellow', 9: 'black', 11:'cyan', 13: 'grey',18: 'magenta', 24: 'darkgrey'}

density = [0.49,0.51]

pl.figure(1,(13,10))
for i,k in enumerate(K[o]):
    M = int(re.findall("_M(\d*?).json",k.name)[0])
    d = float(re.findall("_filled(.*?)_",k.name)[0])
    
    if (d < density[0]) or (d > density[1]):
        continue
    
    if M not in [0] :
        print i,k.name
        simulResults = simplejson.loads(k.get_contents_as_string())
        c = simulResults['output']['cooperation']['c']
        pl.plot(c,ls="-",lw=2 - float(i)/len(K)*1.8,color=colorLine[M],label="%s: M=%s"%(i,M))

pl.xlim(xmax=250)
pl.legend(loc=0)
pl.xlabel("Iterations")
pl.ylabel("Cooperation Level")
#pl.savefig(rootDir + "figures/tSeries_filled0.9_s0.eps")
# Out:
# 3 results/json/simul200_grid49_filled0.50_20150714235927_r0.00_q0.00_m1.00_s0.0000_M1.json
# 7
#  results/json/simul200_grid49_filled0.50_20141002191855_r0.00_q0.00_m1.00_s0.0000_M3.json
# 8
#  results/json/simul200_grid49_filled0.50_20141003011815_r0.00_q0.00_m1.00_s0.0000_M3.json
# 10
#  results/json/simul200_grid49_filled0.50_20150626031257_r0.00_q0.00_m1.00_s0.0000_M3.json
# 11
#  results/json/simul200_grid49_filled0.50_20150626190205_r0.00_q0.00_m1.00_s0.0000_M3.json
# 33
#  results/json/simul200_grid49_filled0.50_20140828003733_r0.00_q0.00_m1.00_s0.00_M5.json
# 52
#  results/json/simul200_grid49_filled0.50_20150624195905_r0.00_q0.00_m1.00_s0.0000_M7.json
# 62
#  results/json/simul200_grid49_filled0.50_20141002194418_r0.00_q0.00_m1.00_s0.0000_M7.json
# 68
#  results/json/simul200_grid49_filled0.50_20150626035315_r0.00_q0.00_m1.00_s0.0000_M9.json
# 90
#  results/json/simul200_grid49_filled0.50_20150628025834_r0.00_q0.00_m1.00_s0.0000_M11.json
# 95
#  results/json/simul200_grid49_filled0.50_20150711231855_r0.00_q0.00_m1.00_s0.0000_M13.json

# %%
parDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            's':0,
            'perc_filled_sites' : 0.9}

K = np.array(searchKeys(parDic))

M = []
for k in K:
    M = np.append(M,int(re.findall("_M(\d*?).json",k.name)[0])) 
o = np.argsort(M)


colorLine ={1:'green',3:'blue',5:'red', 7 : 'yellow', 9: 'black', 11:'cyan', 18: 'magenta' }

iterator = 0

pl.figure(1,(13,10))
for i,k in enumerate(K[o]):
    M = int(re.findall("_M(\d*?).json",k.name)[0])
    #if not M in (2,4,6,8,18):
    if M in [5]:
        simulResults = simplejson.loads(k.get_contents_as_string())
        c = simulResults['output']['cooperation']['c']
        if round(c[0],5) == 0.50995 and iterator == 0 and c[-1] > 0.9:
            iterator = 1
        #if round(c[0],5)!=0.50:    
            print i,k.name,c[0],c[-1]
            pl.plot(c,ls="-",lw=2 - float(i)/len(K)*1.8,label="%s: M=%s"%(i,M))#color=colorLine[M]
        elif round(c[0],5)!=0.50995: 
            print i,k.name,c[0],c[-1]
            pl.plot(c,ls="-",lw=2 - float(i)/len(K)*1.8,label="%s: M=%s"%(i,M))#color=colorLine[M]
            
pl.xlim(xmax=250)
pl.legend(loc=0)
pl.xlabel("Iterations")
pl.ylabel("Cooperation Level")
pl.savefig(rootDir + "figures/tSeries_filled0.9_s0.eps")
# Out:
# 14 results/json/simul200_grid49_filled0.90_20150715042828_r0.00_q0.00_m1.00_s0.0000_M5.json 0.484960666358 0.447478019435
# 15
#  results/json/simul200_grid49_filled0.90_20150716100916_r0.00_q0.00_m1.00_s0.0000_M5.json 0.50994909764 0.991207774179
# 24
#  results/json/simul200_grid49_filled0.90_20150716001627_r0.00_q0.00_m1.00_s0.0000_M5.json 0.501156871819 0.494215640907
# 26
#  results/json/simul200_grid49_filled0.90_20150715010043_r0.00_q0.00_m1.00_s0.0000_M5.json 0.524294308191 0.526608051828
# 27
#  results/json/simul200_grid49_filled0.90_20150714165152_r0.00_q0.00_m1.00_s0.0000_M5.json 0.519666820916 0.573345673299
# 28
#  results/json/simul200_grid49_filled0.90_20150715232526_r0.00_q0.00_m1.00_s0.0000_M5.json 0.501156871819 0.522906062008

# %%
parDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            's':0}

K = np.array(searchKeys(parDic))

M = []
for k in K:
    M = np.append(M,int(re.findall("_M(\d*?).json",k.name)[0])) 
o = np.argsort(M)

colorLine ={1:'green',3:'blue',5:'red', 7 : 'yellow', 9: 'black', 11:'cyan', 18: 'magenta' }

density = [0.9,0.91]

pl.figure(1,(13,10))
matplotlib.rcParams.update({'font.size': 22,'legend.fontsize': 14})

for i,k in enumerate(K[o]):
    M = int(re.findall("_M(\d*?).json",k.name)[0])
    d = float(re.findall("_filled(.*?)_",k.name)[0])
    
    if (d < density[0]) or (d > density[1]):
        continue
    
    #if not M in (2,4,6,8,18):
    if M in [3]:
        simulResults = simplejson.loads(k.get_contents_as_string())
        c = simulResults['output']['cooperation']['c']
        
        print i,k.name,c[0],c[-1]
        pl.plot(c,ls="-",lw=2 - float(i)/len(K)*1.8,label="%s: d=%s"%(i,d))#color=colorLine[M]

pl.xlim(xmax=250)
pl.legend(loc=0)
pl.xlabel("Iterations")
pl.ylabel("Cooperation Level")
pl.savefig(rootDir + "figures/tSeries_filled0.9_s0.eps")
# Out:
# 8 results/json/simul200_grid49_filled0.90_20150715042708_r0.00_q0.00_m1.00_s0.0000_M3.json 0.517815826006 0.962980101805
# 10
#  results/json/simul200_grid49_filled0.90_20150715015846_r0.00_q0.00_m1.00_s0.0000_M3.json 0.516890328552 0.972235076354
# 12
#  results/json/simul200_grid49_filled0.90_20150715014140_r0.00_q0.00_m1.00_s0.0000_M3.json 0.500694123091 0.934752429431
# 19
#  results/json/simul200_grid49_filled0.90_20150626214502_r0.00_q0.00_m1.00_s0.0000_M3.json 0.492827394725 0.96390559926
# 20
#  results/json/simul200_grid49_filled0.90_20150626031826_r0.00_q0.00_m1.00_s0.0000_M3.json 0.517815826006 0.950948634891
# 22
#  results/json/simul200_grid49_filled0.90_20150715004729_r0.00_q0.00_m1.00_s0.0000_M3.json 0.496529384544 0.562239703841
# 25
#  results/json/simul200_grid49_filled0.90_20150716182910_r0.00_q0.00_m1.00_s0.0000_M3.json 0.494215640907 0.903285515965
# 27
#  results/json/simul200_grid49_filled0.90_20150716164449_r0.00_q0.00_m1.00_s0.0000_M3.json 0.480333179084 0.968995835261
# 29
#  results/json/simul200_grid49_filled0.90_20150716173845_r0.00_q0.00_m1.00_s0.0000_M3.json 0.489125404905 0.953262378528

# %%
key = "results/json/simul200_grid49_filled0.90_20141002184536_r0.00_q0.00_m1.00_s0.0000_M5.json"
key = "results/json/simul200_grid49_filled1.00_20150626180346_r0.00_q0.00_m1.00_s0.0000_M3.json"
dic = simplejson.loads(bucket.get_key(key).get_contents_as_string())

# %%
simulResults['output']['cooperation']['c'][0]
# Out:
# 0.5006941230911615

# %%
simulDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            'M':3}

plotTimeSeries(simulDic,density=[0.98,1.1],violations=[-0.1,1.])
# Out:
# 23
# 0 results/json/simul200_grid49_filled1.00_20150626032712_r0.00_q0.00_m1.00_s0.0000_M3.json
# 1
#  results/json/simul200_grid49_filled1.00_20150626180346_r0.00_q0.00_m1.00_s0.0000_M3.json
# 2
#  results/json/simul200_grid49_filled1.00_20150626032446_r0.00_q0.00_m1.00_s0.1000_M3.json
# 3
#  results/json/simul200_grid49_filled1.00_20150626191527_r0.00_q0.00_m1.00_s0.1000_M3.json
# 4
#  results/json/simul200_grid49_filled1.00_20150626035854_r0.00_q0.00_m1.00_s0.2000_M3.json
# 5
#  results/json/simul200_grid49_filled1.00_20150626235350_r0.00_q0.00_m1.00_s0.2000_M3.json
# 6
#  results/json/simul200_grid49_filled1.00_20150626030007_r0.00_q0.00_m1.00_s0.3000_M3.json
# 7
#  results/json/simul200_grid49_filled1.00_20150627000240_r0.00_q0.00_m1.00_s0.3000_M3.json
# 8
#  results/json/simul200_grid49_filled0.98_20150701044308_r0.00_q0.00_m1.00_s0.3976_M3.json
# 9
#  results/json/simul200_grid49_filled1.00_20150626165419_r0.00_q0.00_m1.00_s0.4000_M3.json
# 10
#  results/json/simul200_grid49_filled1.00_20150626201302_r0.00_q0.00_m1.00_s0.4000_M3.json
# 11
#  results/json/simul200_grid49_filled1.00_20150626025316_r0.00_q0.00_m1.00_s0.5000_M3.json
# 12
#  results/json/simul200_grid49_filled1.00_20150626223759_r0.00_q0.00_m1.00_s0.5000_M3.json
# 13
#  results/json/simul200_grid49_filled1.00_20150626051616_r0.00_q0.00_m1.00_s0.6000_M3.json
# 14
#  results/json/simul200_grid49_filled1.00_20150626230240_r0.00_q0.00_m1.00_s0.6000_M3.json
# 15
#  results/json/simul200_grid49_filled1.00_20150626033404_r0.00_q0.00_m1.00_s0.7000_M3.json
# 16
#  results/json/simul200_grid49_filled1.00_20150626232023_r0.00_q0.00_m1.00_s0.7000_M3.json
# 17
#  results/json/simul200_grid49_filled1.00_20150626184541_r0.00_q0.00_m1.00_s0.8000_M3.json
# 18
#  results/json/simul200_grid49_filled1.00_20150627001036_r0.00_q0.00_m1.00_s0.8000_M3.json
# 19
#  results/json/simul200_grid49_filled1.00_20150626234205_r0.00_q0.00_m1.00_s0.9000_M3.json
# 20
#  results/json/simul200_grid49_filled1.00_20150627233751_r0.00_q0.00_m1.00_s0.9000_M3.json
# 21
#  results/json/simul200_grid49_filled1.00_20150626203054_r0.00_q0.00_m1.00_s1.0000_M3.json
# 22
#  results/json/simul200_grid49_filled1.00_20150626211734_r0.00_q0.00_m1.00_s1.0000_M3.json

# %%
simulDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            'M':11}

K = np.array(searchKeys(simulDic))

    
density = [0.40,0.60]

coopAvg = []
coopStd = []

for i,k in enumerate(K):
    #M = int(re.findall("_M(\d*?).json",k.name)[0])
    d = float(re.findall("_filled(.*?)_",k.name)[0])
        
    if (d < density[0]) or (d > density[1]):
        continue
    
    simulResults = simplejson.loads(k.get_contents_as_string())
    
    c = simulResults['output']['cooperation']['c']
    cLast = c[-1]
    print cLast
    if cLast > 0.2 and cLast < 0.6:
        coopAvg = np.append(coopAvg,np.mean(c[100:]))
        coopStd = np.append(coopStd,np.std(c[100:]))

        print i,k.name,c[0],cLast
        pl.plot(c,ls="-",lw=2 - float(i)/len(K)*1.8,label="%s: "%(i))
# Out:
# 0.854318418314
# 0.995837669095
# 0.933333333333
# 0.853125
# 0.878125
# 0.780437044745
# 0.800208116545
# 0.633333333333
# 0.496875
# 139 results/json/simul200_grid49_filled0.40_20150629041319_r0.00_q0.00_m1.00_s0.5500_M11.json [0] 0.496875
# 0.842708333333
# 0.492708333333
# 141 results/json/simul200_grid49_filled0.40_20150629075731_r0.00_q0.00_m1.00_s0.6000_M11.json [0] 0.492708333333
# 0.910416666667
# 0.407291666667
# 143 results/json/simul200_grid49_filled0.40_20150629112223_r0.00_q0.00_m1.00_s0.6500_M11.json [0] 0.407291666667
# 0.773958333333
# 0.003125
# 0.00208333333333
# 0.00104058272633
# 0.00104058272633
# 0.981498612396
# 0.914893617021
# 0.913043478261
# 0.852777777778
# 0.828862164662
# 0.824074074074
# 0.837187789084
# 0.822386679001
# 0.44537037037
# 157 results/json/simul200_grid49_filled0.45_20150629084354_r0.00_q0.00_m1.00_s0.6000_M11.json [0] 0.44537037037
# 0.000925069380204
# 0.865740740741
# 0.792592592593
# 0.00185185185185
# 0.00185185185185
# 0.00277777777778
# 0.481961147086
# 164 results/json/simul200_grid49_filled0.45_20150630040727_r0.00_q0.00_m1.00_s0.5000_M11.json [0] 0.481961147086
# 0.000925069380204
# 0.490286771508
# 166 results/json/simul200_grid49_filled0.45_20150630113206_r0.00_q0.00_m1.00_s0.5500_M11.json [0] 0.490286771508
# 0.00185185185185
# 0.882597835137
# 0.8275
# 0.992506244796
# 0.784166666667
# 0.835833333333
# 0.82
# 0.868442964197
# 0.865
# 0.839300582848
# 0.412989175687
# 177 results/json/simul200_grid49_filled0.50_20150629091606_r0.00_q0.00_m1.00_s0.6000_M11.json [0] 0.412989175687
# 0.490833333333
# 178 results/json/simul200_grid49_filled0.50_20150629130610_r0.00_q0.00_m1.00_s0.5000_M11.json [0] 0.490833333333
# 0.0025
# 0.724396336386
# 0.000832639467111
# 0.000832639467111
# 0.425833333333
# 183 results/json/simul200_grid49_filled0.50_20150630080434_r0.00_q0.00_m1.00_s0.5500_M11.json [0] 0.425833333333
# 0.000833333333333
# 0.00333333333333
# 0.97803030303
# 0.887878787879
# 0.833459500379
# 0.918939393939
# 0.837244511734
# 0.875851627555
# 0.466666666667
# 192 results/json/simul200_grid49_filled0.55_20150628225607_r0.00_q0.00_m1.00_s0.5000_M11.json [0] 0.466666666667
# 0.867524602574
# 0.469696969697
# 194 results/json/simul200_grid49_filled0.55_20150629050718_r0.00_q0.00_m1.00_s0.5500_M11.json [0] 0.469696969697
# 0.872823618471
# 0.738834216503
# 0.741862225587
# 0.00151515151515
# 0.418181818182
# 199 results/json/simul200_grid49_filled0.55_20150630075020_r0.00_q0.00_m1.00_s0.6000_M11.json [0] 0.418181818182
# 0.000757002271007
# 0.00151400454201
# 0.000757575757576
# 0.00151400454201
# 0.995142262318
# 0.843164469119
# 0.871616932686
# 0.866759195003
# 0.854267869535
# 0.873698820264
# 0.892435808466
# 0.523247744622
# 211 results/json/simul200_grid49_filled0.60_20150629000543_r0.00_q0.00_m1.00_s0.5000_M11.json [0] 0.523247744622
# 0.794444444444
# 0.00208188757807
# 0.36641221374
# 214 results/json/simul200_grid49_filled0.60_20150629140917_r0.00_q0.00_m1.00_s0.5500_M11.json [0] 0.36641221374
# 0.795138888889
# 0.815405968078
# 0.36875
# 217 results/json/simul200_grid49_filled0.60_20150629213919_r0.00_q0.00_m1.00_s0.6000_M11.json [0] 0.36875
# 0.00138792505205
# 0.00138888888889
# 0.00277777777778
# 0.000694444444444
# 0.000694444444444

# %%
print np.mean(coopAvg),np.mean(coopStd)
# Out:
# 0.457366310565 0.0321480284973

# %% [markdown]
# ### Phase Transition (M,d,s) = (5,0.5,0.16)

# %% [markdown]
# ### Phase Transition (M,d,s) = (11,0.75,0.45)

# %%
urls = []
for dic  in configList:
    plot_url = export2plotly(dic)
    urls.append(plot_url)
    print plot_url
# Out:
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/116
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/118
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/120
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/122
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/124
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/126
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/128

# %%
parDic = {'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':9}
resultDic = loadResults(parDic)
dic = resultArray(resultDic,['perc_filled_sites','s','cooperators'])
#print len(dic['s'])
x = np.array(dic['perc_filled_sites'])
y = np.array(dic['s'])
z = np.array(dic['cooperators'])

fig = plt.figure(1,(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
ax.set_xlabel('perc_filled_sites')
ax.set_ylabel('s')
ax.set_zlabel('cooperators')
ax.set_xlim(-0.,1.0)
# Out:
# (-0.0, 1.0)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
#from matplotlib.mlab import griddata
from scipy.interpolate import griddata
import numpy as np

y = np.array(dic['s'])
x = np.array(dic['perc_filled_sites'])
z = np.array(dic['cooperators'])

#fig = plt.figure(1,(10,10))
#ax = fig.gca(projection='3d')

xi = np.linspace(min(x), max(x),100)
yi = np.linspace(min(y), max(y),100)

#xi = np.linspace(0.1, 0.65)
#yi = np.linspace(0.1, 0.5)

X, Y = np.meshgrid(xi, yi)
Z = griddata(np.array(zip(*[x, y])), z, (X, Y),method="linear")
Z[Z<0.001]=0
Z[Z>1]=1
Z[np.isnan(Z)]=0
#surf = ax.plot_surface(X, Y, Z, rstride=5, cstride=5, cmap=cm.jet,linewidth=1, antialiased=True)
#ax.set_zlim3d(np.min(Z), np.max(Z))
#fig.colorbar(surf)
pl.figure(1,(15,10))
pl.imshow(Z,origin='lower',extent=(min(x),max(x),min(y),max(y)),vmin=0, vmax=1)
xlabel("Perc_filled")
ylabel("s")
#xlim(0.05,0.9)
#ylim(0.05,0.9)
#pl.xticks(np.linspace(min(x),max(x),5))
#pl.yticks(np.linspace(min(y),max(y),5))
pl.colorbar()
pl.savefig(rootDir + "figures/imshow_M%s.eps"%parDic['M'])

#fig = plt.figure(2,(10,10))
#ax = fig.gca(projection='3d')
#surf = ax.plot_surface(X,-Y, Z, rstride=5, cstride=5, cmap=cm.jet,linewidth=0.2, antialiased=True)
#fig.colorbar(surf)
#ax.set_xlim3d(0.05, 1)
#pl.xlabel("perc_filled_sites")
#pl.ylabel("s")
#pl.savefig(rootDir + "figures/3Dsurface.eps")
