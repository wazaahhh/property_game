# %%
sys.path.append("/home/ubuntu/github/property_game/")
try:
    reload(pgame_analyze_lib)
except:
    import pgame_analyze_lib

from pgame_analyze_lib import *

matplotlib.rcParams.update({'font.size': 14})

rootDir = "/home/ubuntu/github/property_game/"

# %%
from mpl_toolkits.mplot3d import Axes3D
import plotly.plotly as py
from plotly.graph_objs import *
from scipy.interpolate import griddata

# %%
def prepareXYZ(parDic):
    resultDic = loadResults(parDic)
    dic = resultArray(resultDic,['perc_filled_sites','s','cooperators'])
    #print len(dic['s'])
    x = np.array(dic['perc_filled_sites'])
    y = np.array(dic['s'])
    z = np.array(dic['cooperators'])

    xi = np.linspace(min(x), max(x),100)
    yi = np.linspace(min(y), max(y),100)

    #xi = np.linspace(0.1, 0.65)
    #yi = np.linspace(0.1, 0.5)

    X, Y = np.meshgrid(xi, yi)
    Z = griddata(np.array(zip(*[x, y])), z, (X, Y),method="linear")
    Z[Z<0.001]=0
    Z[Z>1]=1
    Z[np.isnan(Z)]=0
    
    return {'X':X,'Y':Y,'Z':Z}

def export2plotly(parDic):
    
    dicXYZ = prepareXYZ(parDic)
    
    data = Data([
        Surface(
            z = dicXYZ['Z'],
            x = dicXYZ['X'],
            y = dicXYZ['Y'],
            name='trace0',
            colorscale=[[0, 'rgb(0,0,131)'], [0.125, 'rgb(0,60,170)'], [0.375, 'rgb(5,255,255)'], [0.625, 'rgb(255,255,0)'], [0.875, 'rgb(250,0,0)'], [1, 'rgb(128,0,0)']]
        )
    ])
    layout = Layout(
        title='ppGame_M%.2f_r%.2f_q%.2f_m%.2f'%(parDic['M'],parDic['r'],parDic['q'],parDic['m']),
        autosize = False,
        width = 1500,
        height = 900,
        margin=Margin(
            l=50,
            r=50,
            b=100,
            t=100,
            pad=4
        ),
        scene=Scene(
            xaxis=XAxis(
                range=[0, 1],
                domain=[1,0],
                title = '',
                #titlefont = Font(size = 18),
                tickfont = Font(size = 14),
                nticks=10,
                gridcolor='rgb(255, 255, 255)',
                gridwidth=2,
                zerolinecolor='rgb(255, 255, 255)',
                zerolinewidth=2
            ),
            yaxis=YAxis(
                title = '',
                #titlefont = Font(size = 18),
                tickfont = Font(size = 14),
                nticks=10,
                gridcolor='rgb(255, 255, 255)',
                gridwidth=2,
                zerolinecolor='rgb(255, 255, 255)',
                zerolinewidth=2
            ),
            zaxis=ZAxis(
                range=[0, 1],
                domain=[0, 1],
                autorange=False,
                title = '',
                #titlefont = Font(size = 18),
                tickfont = Font(size = 14),
                nticks=10,
                gridcolor='rgb(255, 255, 255)',
                gridwidth=2,
                zerolinecolor='rgb(255, 255, 255)',
                zerolinewidth=2
            ),
            bgcolor='rgb(244, 244, 248)'
        )
    )
    fig = Figure(data=data, layout=layout)
    plot_url = py.plot(fig)
    return plot_url


def phase_transition(parDic,dRange=[0.4,0.6]):
    resultDic = loadResults(parDic)
    dic = resultArray(resultDic,['perc_filled_sites','s','cooperators'])
    #print dic.keys()
    d = np.array(dic['perc_filled_sites'])
    c = np.array(dic['cooperators'])
    s = np.array(dic['s'])

    cond = (d >= dRange[0]) * ( d < dRange[1])
    
    s = s[cond]
    c = c[cond]
    
    o = np.argsort(s)
    
    return {'s' : s[o],'c' : c[o]}
    
  

def plotTimeSeries(simulDic,density=[0.46,0.54],violations=[0.155,0.16]):

    K = searchKeys(simulDic)
    l = len(K)
    K2 = []
    D = []
    V= []

    for k in K:
        d = float(re.findall("_filled(.*?)_",k.name)[0])
        v = float(re.findall("_s(.*?)_",k.name)[0])

        if (d < density[0]) or (d > density[1]):
            continue
        elif (v < violations[0]) or (v > violations[1]):
            continue
        else:
            K2 = np.append(K2,k)
            D = np.append(D,d)
            V = np.append(V,v)

    o = np.lexsort([D,V])
    K2 = K2[o]
    V = V[o]
    D = D[o]

    print len(K2)

    pl.figure(1,(15,12))
    matplotlib.rcParams.update({'font.size': 22,'legend.fontsize': 14})

    for i,k in enumerate(K2):
        print i,k.name
        simulResults = simplejson.loads(k.get_contents_as_string())
        c = simulResults['output']['cooperation']['c']
        pl.plot(c,ls="-",lw=2 - float(i)/len(K2)*1.8,label="%s: s=%.4f, d=%.2f"%(i,V[i],D[i]))


    title = "M = %s, %.4f < d < %.4f, %.4f < s < %.4f"%(simulDic['M'],density[0],density[0],violations[0],violations[1])
    pl.plot(np.arange(200),np.zeros([200])+0.5,'k-')
    pl.legend(loc=0)
    pl.xlabel("Iterations")
    pl.ylabel("Cooperation Level")
    pl.xlim(xmax=300)
    pl.title(title)
    #pl.figure(2)
    #pl.plot(np.diff(c))
    pl.savefig(rootDir + "figures/tseries_%s.eps"%title)

# %%
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':3}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':5}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':7}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':9}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':3}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':5}
#parDic = {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':7}

# %%
configList = [{'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':1},
              {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':3},
              {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':5},
              {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':7},
              {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':9},
              {'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':11},
              {'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':13}]
#,
#              {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':3},
#              {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':5},
#              {'iterations' : 200,'grid_size' : 49,'r':0.05,'q':0.05,'m':1.0,'M':7}]

# %%
export2plotly({'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':13})
# Out:
# u'https://plot.ly/~wazaahhh/203'

# %%
dic = resultArray(resultDic,['perc_filled_sites','s','cooperators'])
d = np.array(dic['perc_filled_sites'])
c = np.array(dic['cooperators'])
s = np.array(dic['s'])

c1 = s==0.162
print d[c1]
c2 = s==0.2
print d[c2]
# Out:
# [ 0.5]
# [ 0.7  0.3  0.9  0.2  0.5  0.1  0.1  0.3]

# %%
K = searchKeys({'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':5,'perc_filled_sites':0.5,'s':0.16})

# %%
K
# Out:
# [<Key: property_game,results/json/simul200_grid49_filled0.50_20140826194412_r0.00_q0.00_m1.00_s0.16_M5.json>,
#  <Key: property_game,results/json/simul200_grid49_filled0.50_20140826214622_r0.00_q0.00_m1.00_s0.16_M5.json>,
#  <Key: property_game,results/json/simul200_grid49_filled0.50_20140826223247_r0.00_q0.00_m1.00_s0.16_M5.json>,
#  <Key: property_game,results/json/simul200_grid49_filled0.50_20140826224340_r0.00_q0.00_m1.00_s0.16_M5.json>,
#  <Key: property_game,results/json/simul200_grid49_filled0.50_20140826225113_r0.00_q0.00_m1.00_s0.16_M5.json>,
#  <Key: property_game,results/json/simul200_grid49_filled0.50_20141002180301_r0.00_q0.00_m1.00_s0.1600_M5.json>]

# %%
dic = simplejson.loads(K[3].get_contents_as_string())
print dic['input']['s']
# Out:
# 0.162

# %%
parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'m':1.0,'M':5}
#resultDic = loadResults(parDic)
#dic = resultArray(resultDic,['perc_filled_sites','s','cooperators'])

dic = phase_transition(parDic,dRange=[0.4,0.6])

#d = np.array(dic['perc_filled_sites'])
c = np.array(dic['c'])
s = np.array(dic['s'])

o = np.argsort(c)
index = np.argwhere(c[o] > 0.50)[0]
print c[o][index],s[o][index]

index = np.argwhere(c[o] < 0.50)[-1]
print c[o][index],s[o][index]
# Out:
# [ 0.59416667] [ 0.162]
# [ 0.0041632] [ 0.2]

# %%
resultDic = loadResults(parDic)

# %%
o = np.argsort(output['c'])
index = np.argwhere(c > 0.50)[0]
print c[index]
# Out:
# [ 0.50851393]

# %%
plot(c)

# %%
np.argwhere(output['c']==0.50851393)
# Out:
# array([], shape=(0, 1), dtype=int64)

# %%
parDic = {'iterations' : 200,'grid_size' : 49,'r':0.0,'q':0.0,'M':5}
output = phase_transition(parDic,dRange=[0.4,0.6])
print output
# Out:
# ['s', 'cooperators', 'perc_filled_sites']
# {'s': array([ 0.        ,  0.01      ,  0.02      ,  0.03      ,  0.0323988 ,
#         0.04      ,  0.04463638,  0.05      ,  0.06      ,  0.07      ,
#         0.08      ,  0.09      ,  0.1       ,  0.1       ,  0.11      ,
#         0.12      ,  0.125     ,  0.13      ,  0.14      ,  0.14500444,
#         0.14780892,  0.14815698,  0.14859327,  0.14865632,  0.14894081,
#         0.14947864,  0.14993122,  0.15      ,  0.15      ,  0.15007041,
#         0.15008635,  0.15023209,  0.150259  ,  0.15030322,  0.15031274,
#         0.15052162,  0.15058728,  0.1506378 ,  0.15082413,  0.15109991,
#         0.15139142,  0.15155387,  0.15173935,  0.15182148,  0.15184195,
#         0.15192927,  0.15194034,  0.152     ,  0.15221493,  0.15225126,
#         0.15225576,  0.15227903,  0.15228614,  0.15247488,  0.15249128,
#         0.15254438,  0.15274764,  0.15281332,  0.15282794,  0.15292975,
#         0.15294372,  0.15296705,  0.15302548,  0.15326771,  0.15352209,
#         0.15373672,  0.15381617,  0.154     ,  0.15406228,  0.15407013,
#         0.15419726,  0.15421143,  0.15442817,  0.15462167,  0.15465356,
#         0.15467084,  0.15477353,  0.15479083,  0.15480669,  0.15497422,
#         0.15505369,  0.15536533,  0.15541701,  0.15552617,  0.15555329,
#         0.15564708,  0.156     ,  0.15603827,  0.15612049,  0.15636303,
#         0.15640316,  0.15653318,  0.15661942,  0.15679584,  0.15681204,
#         0.15687423,  0.15687688,  0.15689958,  0.15696389,  0.15718122,
#         0.15724453,  0.15735115,  0.15740948,  0.15745689,  0.15753545,
#         0.15759496,  0.15760667,  0.15780455,  0.15783462,  0.15787724,
#         0.158     ,  0.15803881,  0.15849043,  0.15852724,  0.15857242,
#         0.15865853,  0.15891272,  0.15904546,  0.15905443,  0.15908119,
#         0.15913643,  0.15917962,  0.15946777,  0.1595863 ,  0.1598864 ,
#         0.16      ,  0.16      ,  0.16000144,  0.16008467,  0.16012888,
#         0.16039985,  0.16071414,  0.16078135,  0.162     ,  0.164     ,
#         0.166     ,  0.168     ,  0.16972795,  0.17      ,  0.175     ,
#         0.18      ,  0.19      ,  0.2       ,  0.2       ,  0.21      ,
#         0.22366227,  0.225     ,  0.24073937,  0.25      ,  0.30795105,
#         0.32221087,  0.41210743,  0.42043304,  0.54427507,  0.56775793,
#         0.63351395,  0.63750815,  0.7639631 ,  0.78554436,  0.82630123,
#         0.85631017,  0.94300994,  0.98282926]), 'c': array([  9.95833333e-01,   9.69192340e-01,   9.88343047e-01,
#          9.02500000e-01,   8.72860636e-01,   9.06744380e-01,
#          8.64888124e-01,   8.65112406e-01,   8.64166667e-01,
#          8.34304746e-01,   8.42500000e-01,   7.47710241e-01,
#          7.41881765e-01,   8.36802664e-01,   8.32639467e-01,
#          7.62500000e-01,   7.87676936e-01,   8.01666667e-01,
#          7.93333333e-01,   7.46341463e-01,   7.88126919e-01,
#          6.35235732e-01,   6.96106363e-01,   6.12977099e-01,
#          7.70588235e-01,   7.14796283e-04,   0.00000000e+00,
#          7.60833333e-01,   6.91090758e-01,   7.16049383e-01,
#          3.96825397e-03,   6.19574468e-01,   7.06968934e-01,
#          6.79962013e-01,   7.10227273e-04,   7.28332119e-04,
#          7.45192308e-01,   7.68545994e-01,   1.39372822e-03,
#          0.00000000e+00,   7.08150745e-01,   7.26315789e-01,
#          7.61987794e-01,   6.66666667e-01,   3.15457413e-03,
#          6.69291339e-01,   6.97350070e-04,   6.20316403e-01,
#          2.14132762e-03,   6.52777778e-01,   7.18634686e-01,
#          5.83478261e-01,   3.63901019e-03,   6.46420824e-01,
#          6.82313495e-01,   1.52091255e-03,   3.33055787e-03,
#          7.89265983e-04,   1.51057402e-03,   5.45031056e-01,
#          7.57185332e-01,   6.99215344e-01,   6.57844991e-01,
#          6.97478992e-01,   0.00000000e+00,   5.88932806e-01,
#          6.69097539e-01,   6.54454621e-01,   7.46867168e-01,
#          6.31674208e-01,   7.72200772e-04,   7.19942405e-04,
#          7.44376278e-01,   1.43575018e-03,   6.75585284e-01,
#          5.84737364e-01,   7.12204007e-01,   0.00000000e+00,
#          8.02586207e-01,   3.08324769e-03,   2.27617602e-03,
#          1.47601476e-03,   7.06713781e-04,   6.93116635e-01,
#          6.96378830e-04,   5.90225564e-01,   2.50000000e-03,
#          6.32846088e-01,   6.50755768e-01,   2.09059233e-03,
#          1.43678161e-03,   7.77669903e-01,   6.99702676e-01,
#          6.84893420e-01,   2.41351569e-03,   6.32800000e-01,
#          1.51860289e-03,   7.61864407e-01,   7.50750751e-04,
#          0.00000000e+00,   6.37291280e-01,   5.78947368e-01,
#          1.53139357e-03,   1.69204738e-03,   7.43953294e-01,
#          0.00000000e+00,   7.95935648e-01,   0.00000000e+00,
#          1.49365198e-03,   5.80419580e-01,   0.00000000e+00,
#          1.68350168e-03,   7.16845878e-04,   4.87329435e-03,
#          6.35972461e-01,   7.41839763e-04,   8.01924619e-04,
#          8.21866164e-01,   7.03967447e-01,   6.89446367e-01,
#          5.83412774e-01,   5.85886722e-01,   6.32854578e-01,
#          6.47451963e-01,   1.39958013e-03,   8.33333333e-04,
#          8.32639467e-04,   7.29857820e-01,   5.58158996e-01,
#          1.44092219e-03,   1.45137881e-03,   4.51292247e-01,
#          8.40336134e-04,   5.94166667e-01,   1.66666667e-03,
#          1.66666667e-03,   2.49791840e-03,   2.34192037e-03,
#          8.32639467e-04,   8.32639467e-04,   2.50000000e-03,
#          3.33055787e-03,   4.16319734e-03,   2.49791840e-03,
#          0.00000000e+00,   1.81983621e-03,   0.00000000e+00,
#          2.42326333e-03,   8.33333333e-04,   1.71969046e-03,
#          2.40000000e-03,   7.07714084e-04,   1.66805671e-03,
#          0.00000000e+00,   7.35835173e-04,   9.15750916e-04,
#          7.09723208e-04,   0.00000000e+00,   9.65250965e-04,
#          7.41289844e-04,   0.00000000e+00,   8.16326531e-04,
#          1.91204589e-03])}

# %%
pl.figure(1,(13,10))
matplotlib.rcParams.update({'font.size': 22})
for parDic in configList:
    output = phase_transition(parDic,dRange=[0.4,0.6])
    #print parDic,output['s'],output['c']
    pl.plot(output['s'],output['c'],'s-',label="M=%s"%parDic['M'],lw=1)
pl.ylim(ymin=-0.1)
pl.xlabel("Property Violation s")
pl.ylabel("Cooperation Level after N=200 iterations")
pl.legend()
pl.savefig(rootDir + "figures/phase_transitions.eps")
# Out:
# ['s', 'cooperators', 'perc_filled_sites']
# ['s', 'cooperators', 'perc_filled_sites']
# ['s', 'cooperators', 'perc_filled_sites']
# ['s', 'cooperators', 'perc_filled_sites']
# ['s', 'cooperators', 'perc_filled_sites']
# ['s', 'cooperators', 'perc_filled_sites']
# ['s', 'cooperators', 'perc_filled_sites']

# %%
simulDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            'M':1}


plotTimeSeries(simulDic,density=[0.0,0.1],violations=[0.2,0.7])
# Out:
# 19
# 0 results/json/simul200_grid49_filled0.08_20150701064959_r0.00_q0.00_m1.00_s0.2049_M1.json
# 1
#  results/json/simul200_grid49_filled0.02_20150701064841_r0.00_q0.00_m1.00_s0.2132_M1.json
# 2
#  results/json/simul200_grid49_filled0.02_20150630173030_r0.00_q0.00_m1.00_s0.2353_M1.json
# 3
#  results/json/simul200_grid49_filled0.06_20150701065528_r0.00_q0.00_m1.00_s0.2511_M1.json
# 4
#  results/json/simul200_grid49_filled0.05_20150701064829_r0.00_q0.00_m1.00_s0.2512_M1.json
# 5
#  results/json/simul200_grid49_filled0.08_20150701065758_r0.00_q0.00_m1.00_s0.2879_M1.json
# 6
#  results/json/simul200_grid49_filled0.03_20150701063054_r0.00_q0.00_m1.00_s0.3089_M1.json
# 7
#  results/json/simul200_grid49_filled0.05_20150701065355_r0.00_q0.00_m1.00_s0.3547_M1.json
# 8
#  results/json/simul200_grid49_filled0.07_20150701064335_r0.00_q0.00_m1.00_s0.3561_M1.json
# 9
#  results/json/simul200_grid49_filled0.02_20150630171755_r0.00_q0.00_m1.00_s0.3906_M1.json
# 10
#  results/json/simul200_grid49_filled0.10_20150701070224_r0.00_q0.00_m1.00_s0.3951_M1.json
# 11
#  results/json/simul200_grid49_filled0.02_20150701064455_r0.00_q0.00_m1.00_s0.4039_M1.json
# 12
#  results/json/simul200_grid49_filled0.02_20150701064543_r0.00_q0.00_m1.00_s0.4453_M1.json
# 13
#  results/json/simul200_grid49_filled0.06_20150701064605_r0.00_q0.00_m1.00_s0.4735_M1.json
# 14
#  results/json/simul200_grid49_filled0.00_20150630172907_r0.00_q0.00_m1.00_s0.4892_M1.json
# 15
#  results/json/simul200_grid49_filled0.04_20150701065103_r0.00_q0.00_m1.00_s0.5028_M1.json
# 16
#  results/json/simul200_grid49_filled0.07_20150701065142_r0.00_q0.00_m1.00_s0.5115_M1.json
# 17
#  results/json/simul200_grid49_filled0.05_20150630173431_r0.00_q0.00_m1.00_s0.5385_M1.json
# 18
#  results/json/simul200_grid49_filled0.04_20150630174216_r0.00_q0.00_m1.00_s0.6552_M1.json

# %%
simulDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            'M':5}

plotTimeSeries(simulDic,density=[-0.01,0.1],violations=[-0.00,0.01])
pl.xlim(xmax=50)
# Out:
# 1
# 0 results/json/simul200_grid49_filled0.10_20141002183232_r0.00_q0.00_m1.00_s0.0000_M5.json
# (0.0, 50)

# %% [markdown]
# ### Phase Transition (M,d,s) = (5,0.5,0.16)

# %%
simulDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            'M':5}


plotTimeSeries(simulDic,density=[0.49,0.51],violations=[0.15,0.16])
# Out:
# 25
# 0 results/json/simul200_grid49_filled0.50_20140808061252_r0.00_q0.00_m1.00_s0.15_M5.json
# 1
#  results/json/simul200_grid49_filled0.50_20140826194413_r0.00_q0.00_m1.00_s0.15_M5.json
# 2
#  results/json/simul200_grid49_filled0.50_20140826204754_r0.00_q0.00_m1.00_s0.15_M5.json
# 3
#  results/json/simul200_grid49_filled0.50_20141002173926_r0.00_q0.00_m1.00_s0.1500_M5.json
# 4
#  results/json/simul200_grid49_filled0.49_20150701234031_r0.00_q0.00_m1.00_s0.1502_M5.json
# 5
#  results/json/simul200_grid49_filled0.50_20150702075045_r0.00_q0.00_m1.00_s0.1503_M5.json
# 6
#  results/json/simul200_grid49_filled0.50_20150702021826_r0.00_q0.00_m1.00_s0.1525_M5.json
# 7
#  results/json/simul200_grid49_filled0.50_20150702043024_r0.00_q0.00_m1.00_s0.1527_M5.json
# 8
#  results/json/simul200_grid49_filled0.50_20150702063348_r0.00_q0.00_m1.00_s0.1533_M5.json
# 9
#  results/json/simul200_grid49_filled0.51_20150702023734_r0.00_q0.00_m1.00_s0.1535_M5.json
# 10
#  results/json/simul200_grid49_filled0.50_20150702053339_r0.00_q0.00_m1.00_s0.1541_M5.json
# 11
#  results/json/simul200_grid49_filled0.50_20150702031247_r0.00_q0.00_m1.00_s0.1547_M5.json
# 12
#  results/json/simul200_grid49_filled0.49_20150702083126_r0.00_q0.00_m1.00_s0.1569_M5.json
# 13
#  results/json/simul200_grid49_filled0.49_20150702085531_r0.00_q0.00_m1.00_s0.1575_M5.json
# 14
#  results/json/simul200_grid49_filled0.50_20150702203454_r0.00_q0.00_m1.00_s0.1575_M5.json
# 15
#  results/json/simul200_grid49_filled0.49_20150702083643_r0.00_q0.00_m1.00_s0.1576_M5.json
# 16
#  results/json/simul200_grid49_filled0.50_20150702120958_r0.00_q0.00_m1.00_s0.1576_M5.json
# 17
#  results/json/simul200_grid49_filled0.49_20150702201502_r0.00_q0.00_m1.00_s0.1580_M5.json
# 18
#  results/json/simul200_grid49_filled0.50_20150702100925_r0.00_q0.00_m1.00_s0.1596_M5.json
# 19
#  results/json/simul200_grid49_filled0.50_20140826194412_r0.00_q0.00_m1.00_s0.16_M5.json
# 20
#  results/json/simul200_grid49_filled0.50_20140826214622_r0.00_q0.00_m1.00_s0.16_M5.json
# 21
#  results/json/simul200_grid49_filled0.50_20140826223247_r0.00_q0.00_m1.00_s0.16_M5.json
# 22
#  results/json/simul200_grid49_filled0.50_20140826224340_r0.00_q0.00_m1.00_s0.16_M5.json
# 23
#  results/json/simul200_grid49_filled0.50_20140826225113_r0.00_q0.00_m1.00_s0.16_M5.json
# 24
#  results/json/simul200_grid49_filled0.50_20141002180301_r0.00_q0.00_m1.00_s0.1600_M5.json

# %%
simulDic = {'iterations' : 200,
            'grid_size' : 49,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            'M':7}

plotTimeSeries(simulDic,density=[0.55,0.7],violations=[0.20,0.35])
# Out:
# 16
# 0 results/json/simul200_grid49_filled0.55_20150625004745_r0.00_q0.00_m1.00_s0.2000_M7.json
# 1
#  results/json/simul200_grid49_filled0.60_20150625052127_r0.00_q0.00_m1.00_s0.2000_M7.json
# 2
#  results/json/simul200_grid49_filled0.65_20150625014543_r0.00_q0.00_m1.00_s0.2000_M7.json
# 3
#  results/json/simul200_grid49_filled0.70_20150625004925_r0.00_q0.00_m1.00_s0.2000_M7.json
# 4
#  results/json/simul200_grid49_filled0.55_20150625025922_r0.00_q0.00_m1.00_s0.2500_M7.json
# 5
#  results/json/simul200_grid49_filled0.60_20150625080959_r0.00_q0.00_m1.00_s0.2500_M7.json
# 6
#  results/json/simul200_grid49_filled0.65_20150624223026_r0.00_q0.00_m1.00_s0.2500_M7.json
# 7
#  results/json/simul200_grid49_filled0.70_20150625021803_r0.00_q0.00_m1.00_s0.2500_M7.json
# 8
#  results/json/simul200_grid49_filled0.55_20150625023651_r0.00_q0.00_m1.00_s0.3000_M7.json
# 9
#  results/json/simul200_grid49_filled0.60_20150624234130_r0.00_q0.00_m1.00_s0.3000_M7.json
# 10
#  results/json/simul200_grid49_filled0.65_20150625014251_r0.00_q0.00_m1.00_s0.3000_M7.json
# 11
#  results/json/simul200_grid49_filled0.70_20150625072003_r0.00_q0.00_m1.00_s0.3000_M7.json
# 12
#  results/json/simul200_grid49_filled0.55_20150625035326_r0.00_q0.00_m1.00_s0.3500_M7.json
# 13
#  results/json/simul200_grid49_filled0.60_20150625080554_r0.00_q0.00_m1.00_s0.3500_M7.json
# 14
#  results/json/simul200_grid49_filled0.65_20150625153525_r0.00_q0.00_m1.00_s0.3500_M7.json
# 15
#  results/json/simul200_grid49_filled0.70_20150625090830_r0.00_q0.00_m1.00_s0.3500_M7.json

# %% [markdown]
# ### Phase Transition (M,d,s) = (11,0.75,0.45)

# %%
simulDic = {'iterations' : 200,
            'grid_size' : 49,
            #'perc_filled_sites': 0.5,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            'M':11}

plotTimeSeries(simulDic,density=[0.65,0.85],violations=[0.35,0.55])
# Out:
# 25
# 0 results/json/simul200_grid49_filled0.65_20150628074941_r0.00_q0.00_m1.00_s0.3500_M11.json
# 1
#  results/json/simul200_grid49_filled0.70_20150628210659_r0.00_q0.00_m1.00_s0.3500_M11.json
# 2
#  results/json/simul200_grid49_filled0.75_20150629161118_r0.00_q0.00_m1.00_s0.3500_M11.json
# 3
#  results/json/simul200_grid49_filled0.80_20150629000550_r0.00_q0.00_m1.00_s0.3500_M11.json
# 4
#  results/json/simul200_grid49_filled0.85_20150629162247_r0.00_q0.00_m1.00_s0.3500_M11.json
# 5
#  results/json/simul200_grid49_filled0.65_20150629191137_r0.00_q0.00_m1.00_s0.4000_M11.json
# 6
#  results/json/simul200_grid49_filled0.70_20150628233222_r0.00_q0.00_m1.00_s0.4000_M11.json
# 7
#  results/json/simul200_grid49_filled0.75_20150628134829_r0.00_q0.00_m1.00_s0.4000_M11.json
# 8
#  results/json/simul200_grid49_filled0.80_20150629012403_r0.00_q0.00_m1.00_s0.4000_M11.json
# 9
#  results/json/simul200_grid49_filled0.85_20150628231549_r0.00_q0.00_m1.00_s0.4000_M11.json
# 10
#  results/json/simul200_grid49_filled0.65_20150629122212_r0.00_q0.00_m1.00_s0.4500_M11.json
# 11
#  results/json/simul200_grid49_filled0.70_20150629141617_r0.00_q0.00_m1.00_s0.4500_M11.json
# 12
#  results/json/simul200_grid49_filled0.75_20150629150404_r0.00_q0.00_m1.00_s0.4500_M11.json
# 13
#  results/json/simul200_grid49_filled0.80_20150630021451_r0.00_q0.00_m1.00_s0.4500_M11.json
# 14
#  results/json/simul200_grid49_filled0.85_20150628181434_r0.00_q0.00_m1.00_s0.4500_M11.json
# 15
#  results/json/simul200_grid49_filled0.65_20150629050305_r0.00_q0.00_m1.00_s0.5000_M11.json
# 16
#  results/json/simul200_grid49_filled0.70_20150629051207_r0.00_q0.00_m1.00_s0.5000_M11.json
# 17
#  results/json/simul200_grid49_filled0.75_20150629134337_r0.00_q0.00_m1.00_s0.5000_M11.json
# 18
#  results/json/simul200_grid49_filled0.80_20150630035227_r0.00_q0.00_m1.00_s0.5000_M11.json
# 19
#  results/json/simul200_grid49_filled0.85_20150630051916_r0.00_q0.00_m1.00_s0.5000_M11.json
# 20
#  results/json/simul200_grid49_filled0.65_20150630091036_r0.00_q0.00_m1.00_s0.5500_M11.json
# 21
#  results/json/simul200_grid49_filled0.70_20150629171452_r0.00_q0.00_m1.00_s0.5500_M11.json
# 22
#  results/json/simul200_grid49_filled0.75_20150630064144_r0.00_q0.00_m1.00_s0.5500_M11.json
# 23
#  results/json/simul200_grid49_filled0.80_20150629213528_r0.00_q0.00_m1.00_s0.5500_M11.json
# 24
#  results/json/simul200_grid49_filled0.85_20150629183126_r0.00_q0.00_m1.00_s0.5500_M11.json

# %%
simulDic = {'iterations' : 200,
            'grid_size' : 49,
            #'perc_filled_sites': 0.5,
            'r':0.0,
            'q':0.0,
            'm':1.0,
            'M':13}

plotTimeSeries(simulDic,density=[0.35,0.45],violations=[0.4,0.8])
# Out:
# 7
# 0 results/json/simul200_grid49_filled0.36_20150704224900_r0.00_q0.00_m1.00_s0.4740_M13.json
# 1
#  results/json/simul200_grid49_filled0.39_20150704023710_r0.00_q0.00_m1.00_s0.5311_M13.json
# 2
#  results/json/simul200_grid49_filled0.36_20150705150538_r0.00_q0.00_m1.00_s0.6678_M13.json
# 3
#  results/json/simul200_grid49_filled0.45_20150705162057_r0.00_q0.00_m1.00_s0.6704_M13.json
# 4
#  results/json/simul200_grid49_filled0.45_20150706043455_r0.00_q0.00_m1.00_s0.6704_M13.json
# 5
#  results/json/simul200_grid49_filled0.44_20150706020416_r0.00_q0.00_m1.00_s0.6842_M13.json
# 6
#  results/json/simul200_grid49_filled0.38_20150703222711_r0.00_q0.00_m1.00_s0.7439_M13.json

# %%
urls = []
for dic  in configList:
    plot_url = export2plotly(dic)
    urls.append(plot_url)
    print plot_url
# Out:
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/116
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/118
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/120
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/122
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/124
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/126
# loading result dictionary from S3
# https://plot.ly/~wazaahhh/128

# %%
parDic = {'iterations' : 200,'grid_size' : 49,'r':0.00,'q':0.00,'m':1.0,'M':18}
resultDic = loadResults(parDic)
dic = resultArray(resultDic,['perc_filled_sites','s','cooperators'])
#print len(dic['s'])
x = np.array(dic['perc_filled_sites'])
y = np.array(dic['s'])
z = np.array(dic['cooperators'])

fig = plt.figure(1,(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
ax.set_xlabel('perc_filled_sites')
ax.set_ylabel('s')
ax.set_zlabel('cooperators')
ax.set_xlim(-0.,1.0)
# Out:
# dictionary not found on S3; processing data; please wait
# 0
#  24 <Key: property_game,results/json/simul200_grid49_filled0.11_20150708055849_r0.00_q0.00_m1.00_s0.0025_M18.json>
# 1
#  24 <Key: property_game,results/json/simul200_grid49_filled0.11_20150708162614_r0.00_q0.00_m1.00_s0.3224_M18.json>
# 2
#  24 <Key: property_game,results/json/simul200_grid49_filled0.11_20150708165919_r0.00_q0.00_m1.00_s0.1943_M18.json>
# 3
#  24 <Key: property_game,results/json/simul200_grid49_filled0.17_20150708055847_r0.00_q0.00_m1.00_s0.2045_M18.json>
# 4
#  24 <Key: property_game,results/json/simul200_grid49_filled0.24_20150708022936_r0.00_q0.00_m1.00_s0.0109_M18.json>
# 5
#  24 <Key: property_game,results/json/simul200_grid49_filled0.27_20150708172946_r0.00_q0.00_m1.00_s0.2906_M18.json>
# 6
#  24 <Key: property_game,results/json/simul200_grid49_filled0.33_20150708022935_r0.00_q0.00_m1.00_s0.0834_M18.json>
# 7
#  24 <Key: property_game,results/json/simul200_grid49_filled0.35_20150708120829_r0.00_q0.00_m1.00_s0.1290_M18.json>
# 8
#  24 <Key: property_game,results/json/simul200_grid49_filled0.43_20150708133133_r0.00_q0.00_m1.00_s0.2722_M18.json>
# 9
#  24 <Key: property_game,results/json/simul200_grid49_filled0.44_20150708082720_r0.00_q0.00_m1.00_s0.0091_M18.json>
# 10
#  24 <Key: property_game,results/json/simul200_grid49_filled0.44_20150708162334_r0.00_q0.00_m1.00_s0.3420_M18.json>
# 11
#  24 <Key: property_game,results/json/simul200_grid49_filled0.47_20150708022941_r0.00_q0.00_m1.00_s0.1391_M18.json>
# 12
#  24 <Key: property_game,results/json/simul200_grid49_filled0.54_20150708123055_r0.00_q0.00_m1.00_s0.1088_M18.json>
# 13
#  24 <Key: property_game,results/json/simul200_grid49_filled0.59_20150708071720_r0.00_q0.00_m1.00_s0.0262_M18.json>
# 14
#  24 <Key: property_game,results/json/simul200_grid49_filled0.65_20150708022935_r0.00_q0.00_m1.00_s0.0870_M18.json>
# 15
#  24 <Key: property_game,results/json/simul200_grid49_filled0.66_20150708140504_r0.00_q0.00_m1.00_s0.2325_M18.json>
# 16
#  24 <Key: property_game,results/json/simul200_grid49_filled0.67_20150708101925_r0.00_q0.00_m1.00_s0.1650_M18.json>
# 17
#  24 <Key: property_game,results/json/simul200_grid49_filled0.71_20150708055846_r0.00_q0.00_m1.00_s0.0881_M18.json>
# 18
#  24 <Key: property_game,results/json/simul200_grid49_filled0.73_20150708055845_r0.00_q0.00_m1.00_s0.1843_M18.json>
# 19
#  24 <Key: property_game,results/json/simul200_grid49_filled0.80_20150708022935_r0.00_q0.00_m1.00_s0.0270_M18.json>
# 20
#  24 <Key: property_game,results/json/simul200_grid49_filled0.84_20150708061005_r0.00_q0.00_m1.00_s0.2110_M18.json>
# 21
#  24 <Key: property_game,results/json/simul200_grid49_filled0.84_20150708134150_r0.00_q0.00_m1.00_s0.1414_M18.json>
# 22
#  24 <Key: property_game,results/json/simul200_grid49_filled0.95_20150708055849_r0.00_q0.00_m1.00_s0.0522_M18.json>
# 23
#  24 <Key: property_game,results/json/simul200_grid49_filled1.00_20150708104747_r0.00_q0.00_m1.00_s0.1674_M18.json>
# (-0.0, 1.0)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt
#from matplotlib.mlab import griddata
from scipy.interpolate import griddata
import numpy as np

y = np.array(dic['s'])
x = np.array(dic['perc_filled_sites'])
z = np.array(dic['cooperators'])

#fig = plt.figure(1,(10,10))
#ax = fig.gca(projection='3d')

xi = np.linspace(min(x), max(x),100)
yi = np.linspace(min(y), max(y),100)

#xi = np.linspace(0.1, 0.65)
#yi = np.linspace(0.1, 0.5)

X, Y = np.meshgrid(xi, yi)
Z = griddata(np.array(zip(*[x, y])), z, (X, Y),method="linear")
Z[Z<0.001]=0
Z[Z>1]=1
Z[np.isnan(Z)]=0
#surf = ax.plot_surface(X, Y, Z, rstride=5, cstride=5, cmap=cm.jet,linewidth=1, antialiased=True)
#ax.set_zlim3d(np.min(Z), np.max(Z))
#fig.colorbar(surf)
pl.figure(1,(15,10))
pl.imshow(Z,origin='lower',extent=(min(x),max(x),min(y),max(y)),vmin=0, vmax=1)
xlabel("Perc_filled")
ylabel("s")
ylim(ymax=0.9)
#pl.xticks(np.linspace(min(x),max(x),5))
#pl.yticks(np.linspace(min(y),max(y),5))
pl.colorbar()
pl.savefig(rootDir + "figures/imshow.eps")

fig = plt.figure(2,(10,10))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X,-Y, Z, rstride=5, cstride=5, cmap=cm.jet,linewidth=0.2, antialiased=True)
fig.colorbar(surf)
ax.set_xlim3d(0, 1)
#pl.xlabel("perc_filled_sites")
#pl.ylabel("s")
pl.savefig(rootDir + "figures/3Dsurface.eps")
